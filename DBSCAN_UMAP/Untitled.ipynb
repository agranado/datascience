# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-0074c9bc0b31> in <module>
# ----> 1 import scanpy as sc
#
# ~/anaconda3/lib/python3.7/site-packages/scanpy/__init__.py in <module>
#       1 # some technical stuff
#       2 import sys
# ----> 3 from .utils import check_versions, annotate_doc_types
#       4 from ._version import get_versions  # version generated by versioneer
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/scanpy/utils.py in <module>
#      11 from typing import Union, Callable, Optional
#      12
# ---> 13 import numpy as np
#      14 from scipy import sparse
#      15 from natsort import natsorted
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/__init__.py in <module>
#     156     from . import _distributor_init
#     157
# --> 158     from . import core
#     159     from .core import *
#     160     from . import compat
#
# ...
